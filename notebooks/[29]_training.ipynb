# %%
import sys
sys.path.append('../src/')

# %%
from random_graph import RandGraph
from deep_q_learning import DQN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Graph

# %%
g = RandGraph(actors=50000, graph_type='simple')

# %%
g.plot()
plt.show()

# %% [markdown]
# ## Train

# %%
dqn = DQN(g)

# %%
dqn.train(20000)

# %% [markdown]
# ## Analyse reward

# %%
pd.DataFrame(dqn.total_rewards).rolling(500).mean().plot()
plt.show()
