# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import sys
import random
sys.path.append('../src/')
from random_graph import RandGraph
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
g = RandGraph(actors=200, moving=5, n_paths=10)

# %%
data, nodes = g.step(n=40)

# %%
df = pd.DataFrame(data, columns=nodes)

# %%
sns.heatmap(df, cmap='Blues')
plt.show()

# %%
g.plot()

# %%
df.plot(kind='line')
plt.show()

# %%
nodes_degree = [nx.degree(g.graph,n) for n in range(9,20)]

# %%
plt.scatter(nodes_degree, df.mean(), cmap='b')
# plt.scatter(nodes_degree, df.min(), cmap='g')
# plt.scatter(nodes_degree, df.max(), cmap='r')

plt.show()

# %%
sns.heatmap(df.corr(), cmap='Blues')
plt.show()
