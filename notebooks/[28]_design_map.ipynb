# %%
import networkx as nx
import sys
import random
sys.path.append('../src/')
from random_graph import RandGraph
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
g = RandGraph(graph_type='hongo_district', actors=100)

# %%
g.plot(fig_size=(16,16))
